# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
numericos = titanic.select_dtypes(include = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64'])
print("las columnas numéricas son:", numericos.columns)
# Out:
# las columnas numéricas son: Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
categoricos = titanic.select_dtypes(include = 'object')
categoricos.columns
print("las columnas categóricas son:",categoricos.columns)
# Out:
# las columnas categóricas son: Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
plt.style.use("classic")
plt.rcParams['figure.figsize'] = (12, 6)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
plt.hist(titanic['Age'])
# Out:
# (array([ 72.,  78., 326., 347., 220., 136.,  75.,  42.,  10.,   3.]),
#  array([ 0.17 ,  8.153, 16.136, 24.119, 32.102, 40.085, 48.068, 56.051,
#         64.034, 72.017, 80.   ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
plt.subplot(1,3,1)
titanic['Age'].hist(bins= 10)
plt.subplot(1,3,2)
titanic['Age'].hist(bins= 20)
plt.subplot(1,3,3)
titanic['Age'].hist(bins = 50)

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %% [markdown]
# The bigger the bins are, the better visualization of the distribution

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
sns.distplot(titanic["Age"])

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
titanic["Gender"].value_counts().plot(kind="bar")

# %%
sns.countplot(x="Gender", data=titanic);

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
titanic["Pclass"].value_counts().plot(kind="bar")

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
sns.boxplot(x = "Age",data =  titanic)

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %% [markdown]
# La media de edad de los viajeros se acerca a los 30 año. La edad mínima se acerca a 0 y la máxima a 60. El percentil 75 se encuetnra en torno a los 36 años y el 25 en torno a los 22 años. Exiten valores atípicos desde los 60 a los 80.

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
sns.violinplot(titanic["Age"])

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %% [markdown]
# Se observa que el intervalo intercuartilico está entre los 22 y los 36 años. La mediana está en torno a los 35 años.Con un 95 % de confianza la edad de la gente del barco estaba entre los 0 y los 60 años.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
titanic.plot.scatter(x= "Fare", y = "Age")

# %%
sns.jointplot("Fare", "Age", data= titanic)

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#tita = sns.load_dataset("titanic")
#tita1 = tita.pivot("Pclass","Survived")
tita3=titanic[["Age", "Fare", "Pclass"]]
tita2 = sns.heatmap(tita3.corr())
plt.show()

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %% [markdown]
# La mayor correlación se encuentra en la edad frente a la clase del billete. Se trata de una correlación negativa.

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
sns.boxplot(x = "Pclass", y = "Age",data =  titanic)

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
l = sns.FacetGrid(data = titanic, col = "Gender")
l.map(plt.hist, "Age")
